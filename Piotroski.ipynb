# %%
print("**************************************************PIOTROSKI TRADING ALGORITHM**************************************************\n")
option=int(input("\n1. Piotroski F-Score on Year End Report\n2. Piotroski F-Score on Quareterly Generated Report\n3. Exit \n"))
if(option==1):
    print("\n*********************************************Piotroski F-Score on Year End Report**********************************************\n")
elif(option==2):
    print("\n***************************************Piotroski F-Score on Quareterly Generated Report****************************************\n")
else:
    print("\nProgram Successfully Exited\n")
# Out:
# **************************************************PIOTROSKI TRADING ALGORITHM**************************************************
#
#
# 1. Piotroski F-Score on Year End Report
# 2. Piotroski F-Score on Quareterly Generated Report
# 3. Exit
# 3
# Program Successfully Exited

# %%
year=int(input("Enter the year of Financial Report "))
score=0
#Obtaining Figures
net_income1=float(input(f"Enter the Net Income for {year} " ))
net_income2=float(input(f"Enter the Net Income for {year-1} " ))

cfo=float(input(f"Enter Cash Flow from Operations for {year} " ))

assets1=float(input(f"Enter the Total Assets for {year} " ))
assets2=float(input(f"Enter the Total Assets for {year-1} " ))
assets3=float(input(f"Enter the Total Assets for {year-2} " ))

long_term_debt1=float(input(f"Enter Long Term Debts for {year} " ))
long_term_debt2=float(input(f"Enter Long Term Debts for {year-1} " ))

current_assets1=float(input(f"Enter Total Current Assets for {year} " ))
current_assets2=float(input(f"Enter Total Current Assets for {year-1} " ))
current_assets3=float(input(f"Enter Total Current Assets for {year-2} " ))

current_liabilities1=float(input(f"Enter Total Liabilities for {year} " ))
current_liabilities2=float(input(f"Enter Total Liabilities for {year-1} " ))

gross_profit1=float(input(f"Enter Gross Profit for {year} " ))
gross_profit2=float(input(f"Enter Gross Profit for {year-1} " ))

revenue1=float(input(f"Enter revenue for {year} " ))
revenue2=float(input(f"Enter revenue for {year-1} " ))

#Start of Calculation

avg_current_assets1=(current_assets1+current_assets2)/2
avg_current_assets2=(current_assets3+current_assets2)/2

avg_assets1=(assets1+assets2)/2
avg_assets2=(assets2+assets3)/2

cash_flow_op=cfo/avg_assets1

roa1=net_income1/avg_assets1
roa2=net_income2/avg_assets2
delta_roa=roa1-abs(roa2)

accruals=roa1-abs(cash_flow_op)

leverage1=long_term_debt1/avg_assets1
leverage2=long_term_debt2/avg_assets2
delta_leverage=leverage1-abs(leverage2)

current_ratio1=((current_assets1+current_assets2)/2)/current_liabilities1
current_ratio2=((current_assets3+current_assets2)/2)/current_liabilities2
delta_liquidity=current_ratio1-abs(current_ratio2)

gmo1=gross_profit1/revenue1
gmo2=gross_profit2/revenue2
delta_gmo=gmo1-abs(gmo2)

atr1=revenue1/avg_assets1
atr2=revenue2/avg_assets2
atr=atr1-abs(atr2)

op=input("Did the company have an equity carve-out in last two years?(Y/N) ")


print("\n*************************************************Piotroski F-Score*************************************************\n")
print(f"The ROA of the company for the year {year} is {round(roa1,3)}")
print(f"The CFO of the company for the year {year} is {round(cash_flow_op,3)}" )
print(f"The Delta ROA of the company for the year {year} is {delta_roa}" )
print(f"The Accruals of the company for the year {year} is {accruals}" )
print(f"The Delta Liquidity of the company for the year {year} is {delta_liquidity}" )
print(f"The Delta Leverage of the company for the year {year} is {delta_leverage}" )
print(f"The Delta Gross Margin of the company for the year {year} is {delta_gmo}" )
print(f"The Delta Asset Turnover Ratio of the company for the year {year} is {atr}\n" )

print(f"\nThe Current Ratio of the company for the year {year} is {current_ratio1}" )
print(f"The Leverage of the company for the year {year} is {leverage1}" )
print(f"The Gross Margin of the company for the year {year} is {gmo1}" )
print(f"The Asset Turnover Ratio of the company for the year {year} is {atr1}" )

if(round(roa1,2)>0):
    score=score+1
print(score)
if(round(cash_flow_op,2)>0):
    score=score+1
print(score)
if(delta_roa>0):
    score=score+1
print(score)
if(accruals<0):
    score=score+1
print(score)
if(delta_leverage<0):
    score=score+1
print(score)
if(delta_liquidity>0):
    score=score+1
print(score)
if(delta_gmo>0):
    score=score+1
print(score)
if(atr>0):
    score=score+1
print(score)
if(op=="N"):
    score=score+1
print(score)


print("The Piotroski F-Score is ", score)
if(score>=8):
    print("It is expected of you to long this stock ")
if(score<=2):
    print("It is expected of you to short this stock ")
# Out:
# Enter the year of Financial Report 2018
# Enter the Net Income for 2018 225
# Enter the Net Income for 2017 6426
# Enter Cash Flow from Operations for 2018 4992
# Enter the Total Assets for 2018 2602568
# Enter the Total Assets for 2017 2441286
# Enter the Total Assets for 2016 2135823
# Enter Long Term Debts for 2018 619637
# Enter Long Term Debts for 2017 594837
# Enter Total Current Assets for 2018 427623
# Enter Total Current Assets for 2017 264334
# Enter Total Current Assets for 2016 316094
# Enter Total Liabilities for 2018 826157
# Enter Total Liabilities for 2017 761035
# Enter Gross Profit for 2018 546
# Enter Gross Profit for 2017 7106
# Enter revenue for 2018 49431
# Enter revenue for 2017 47662
# Did the company have an equity carve-out in last two years?(Y/N) Y
#
# *************************************************Piotroski F-Score*************************************************
#
# The ROA of the company for the year 2018 is 0.0
# ...

# %%
print("**************************************************PIOTROSKI TRADING ALGORITHM**************************************************\n")
option=int(input("\n1. Piotroski F-Score on Year End Report\n2. Piotroski F-Score on Quareterly Generated Report\n3. Exit \n"))
if(option==1):
    print("\n*********************************************Piotroski F-Score on Year End Report**********************************************\n")
    year=int(input("Enter the year of Financial Report "))
    score=0
    #Obtaining Figures
    net_income1=float(input(f"Enter the Net Income for {year} " ))
    net_income2=float(input(f"Enter the Net Income for {year-1} " ))

    cfo=float(input(f"Enter Cash Flow from Operations for {year} " ))

    assets1=float(input(f"Enter the Total Assets for {year} " ))
    assets2=float(input(f"Enter the Total Assets for {year-1} " ))
    assets3=float(input(f"Enter the Total Assets for {year-2} " ))

    long_term_debt1=float(input(f"Enter Long Term Debts for {year} " ))
    long_term_debt2=float(input(f"Enter Long Term Debts for {year-1} " ))

    current_assets1=float(input(f"Enter Total Current Assets for {year} " ))
    current_assets2=float(input(f"Enter Total Current Assets for {year-1} " ))
    current_assets3=float(input(f"Enter Total Current Assets for {year-2} " ))

    current_liabilities1=float(input(f"Enter Total Liabilities for {year} " ))
    current_liabilities2=float(input(f"Enter Total Liabilities for {year-1} " ))

    gross_profit1=float(input(f"Enter Gross Profit for {year} " ))
    gross_profit2=float(input(f"Enter Gross Profit for {year-1} " ))

    revenue1=float(input(f"Enter revenue for {year} " ))
    revenue2=float(input(f"Enter revenue for {year-1} " ))

    #Start of Calculation

    avg_current_assets1=(current_assets1+current_assets2)/2
    avg_current_assets2=(current_assets3+current_assets2)/2

    avg_assets1=(assets1+assets2)/2
    avg_assets2=(assets2+assets3)/2

    cash_flow_op=cfo/avg_assets1

    roa1=net_income1/avg_assets1
    roa2=net_income2/avg_assets2
    delta_roa=roa1-abs(roa2)

    accruals=roa1-abs(cash_flow_op)

    leverage1=long_term_debt1/avg_assets1
    leverage2=long_term_debt2/avg_assets2
    delta_leverage=leverage1-abs(leverage2)

    current_ratio1=((current_assets1+current_assets2)/2)/current_liabilities1
    current_ratio2=((current_assets3+current_assets2)/2)/current_liabilities2
    delta_liquidity=current_ratio1-abs(current_ratio2)

    gmo1=gross_profit1/revenue1
    gmo2=gross_profit2/revenue2
    delta_gmo=gmo1-abs(gmo2)

    atr1=revenue1/avg_assets1
    atr2=revenue2/avg_assets2
    atr=atr1-abs(atr2)

    op=input("Did the company have an equity carve-out in last two years?(Y/N) ")


    print("\n*************************************************Piotroski F-Score*************************************************\n")
    print(f"The ROA of the company for the year {year} is {round(roa1,3)}")
    print(f"The CFO of the company for the year {year} is {round(cash_flow_op,3)}" )
    print(f"The Delta ROA of the company for the year {year} is {delta_roa}" )
    print(f"The Accruals of the company for the year {year} is {accruals}" )
    print(f"The Delta Liquidity of the company for the year {year} is {delta_liquidity}" )
    print(f"The Delta Leverage of the company for the year {year} is {delta_leverage}" )
    print(f"The Delta Gross Margin of the company for the year {year} is {delta_gmo}" )
    print(f"The Delta Asset Turnover Ratio of the company for the year {year} is {atr}\n" )

    print(f"\nThe Current Ratio of the company for the year {year} is {current_ratio1}" )
    print(f"The Leverage of the company for the year {year} is {leverage1}" )
    print(f"The Gross Margin of the company for the year {year} is {gmo1}" )
    print(f"The Asset Turnover Ratio of the company for the year {year} is {atr1}\n" )

    if(round(roa1,2)>0):
        score=score+1
    if(round(cash_flow_op,2)>0):
        score=score+1
    if(delta_roa>0):
        score=score+1
    if(accruals<0):
        score=score+1
    if(delta_leverage<0):
        score=score+1
    if(delta_liquidity>0):
        score=score+1
    if(delta_gmo>0):
        score=score+1
    if(atr>0):
        score=score+1
    if(op=="N"):
        score=score+1


    print("\nThe Piotroski F-Score is ", score)
    if(score>=8):
        print("It is expected of you to long this stock ")
    if(score<=2):
        print("It is expected of you to short this stock ")

elif(option==2):
    print("\n***************************************Piotroski F-Score on Quareterly Generated Report****************************************\n")
    year=int(input("Enter the year of Financial Report "))
    quarter=int(input("Enter the Quarter of Financial Report "))
    score=0
    if(quarter-1!=0 and quarter-2!=0 and quarter<=4):
        #Obtaining Figures
        net_income1=float(input(f"Enter the Net Income for {year} Q{quarter} " ))
        net_income2=float(input(f"Enter the Net Income for {year} Q{quarter-1} " ))

        cfo=float(input(f"Enter Cash Flow from Operations for {year} Q{quarter} " ))

        assets1=float(input(f"Enter the Total Assets for {year} Q{quarter} " ))
        assets2=float(input(f"Enter the Total Assets for {year} Q{quarter-1} " ))
        assets3=float(input(f"Enter the Total Assets for {year} Q{quarter-2} " ))

        long_term_debt1=float(input(f"Enter Long Term Debts for {year} Q{quarter} " ))
        long_term_debt2=float(input(f"Enter Long Term Debts for {year} Q{quarter-1} " ))

        current_assets1=float(input(f"Enter Total Current Assets for {year} Q{quarter} " ))
        current_assets2=float(input(f"Enter Total Current Assets for {year} Q{quarter-1} " ))
        current_assets3=float(input(f"Enter Total Current Assets for {year} Q{quarter-2} " ))

        current_liabilities1=float(input(f"Enter Total Liabilities for {year} Q{quarter} " ))
        current_liabilities2=float(input(f"Enter Total Liabilities for {year} Q{quarter-1} " ))

        gross_profit1=float(input(f"Enter Gross Profit for {year} Q{quarter} " ))
        gross_profit2=float(input(f"Enter Gross Profit for {year} Q{quarter-1} " ))

        revenue1=float(input(f"Enter revenue for {year} Q{quarter} " ))
        revenue2=float(input(f"Enter revenue for {year} Q{quarter-1} " ))

        #Start of Calculation

        avg_current_assets1=(current_assets1+current_assets2)/2
        avg_current_assets2=(current_assets3+current_assets2)/2

        avg_assets1=(assets1+assets2)/2
        avg_assets2=(assets2+assets3)/2

        cash_flow_op=cfo/avg_assets1

        roa1=net_income1/avg_assets1
        roa2=net_income2/avg_assets2
        delta_roa=roa1-abs(roa2)

        accruals=roa1-abs(cash_flow_op)

        leverage1=long_term_debt1/avg_assets1
        leverage2=long_term_debt2/avg_assets2
        delta_leverage=leverage1-abs(leverage2)

        current_ratio1=((current_assets1+current_assets2)/2)/current_liabilities1
        current_ratio2=((current_assets3+current_assets2)/2)/current_liabilities2
        delta_liquidity=current_ratio1-abs(current_ratio2)

        gmo1=gross_profit1/revenue1
        gmo2=gross_profit2/revenue2
        delta_gmo=gmo1-abs(gmo2)

        atr1=revenue1/avg_assets1
        atr2=revenue2/avg_assets2
        atr=atr1-abs(atr2)

        op=input("Did the company have an equity carve-out in last two years?(Y/N) ")


        print("\n*************************************************Piotroski F-Score*************************************************\n")
        print(f"The ROA of the company for {year} Q{quarter} is {round(roa1,3)}")
        print(f"The CFO of the company for {year} Q{quarter} is {round(cash_flow_op,3)}" )
        print(f"The Delta ROA of the company for {year} Q{quarter} is {delta_roa}" )
        print(f"The Accruals of the company for {year} Q{quarter} is {accruals}" )
        print(f"The Delta Liquidity of the company for {year} Q{quarter} is {delta_liquidity}" )
        print(f"The Delta Leverage of the company for {year} Q{quarter} is {delta_leverage}" )
        print(f"The Delta Gross Margin of the company for {year} Q{quarter} is {delta_gmo}" )
        print(f"The Delta Asset Turnover Ratio of the company for {year} Q{quarter} is {atr}\n" )

        print(f"\nThe Current Ratio of the company for {year} Q{quarter} is {current_ratio1}" )
        print(f"The Leverage of the company for {year} Q{quarter} is {leverage1}" )
        print(f"The Gross Margin of the company for {year} Q{quarter} is {gmo1}" )
        print(f"The Asset Turnover Ratio of the company for {year} Q{quarter} is {atr1}" )

        if(round(roa1,2)>0):
            score=score+1
        if(round(cash_flow_op,2)>0):
            score=score+1
        if(delta_roa>0):
            score=score+1
        if(accruals<0):
            score=score+1
        if(delta_leverage<0):
            score=score+1
        if(delta_liquidity>0):
            score=score+1
        if(delta_gmo>0):
            score=score+1
        if(atr>0):
            score=score+1
        if(op=="N"):
            score=score+1


        print("The Piotroski F-Score is ", score)
        if(score>=8):
            print("It is expected of you to long this stock ")
        if(score<=2):
            print("It is expected of you to short this stock ")
    elif(quarter-1==0):

        net_income1=float(input(f"Enter the Net Income for {year} Q{quarter} " ))
        net_income2=float(input(f"Enter the Net Income for {year-1} Q4 " ))

        cfo=float(input(f"Enter Cash Flow from Operations for {year} Q{quarter} " ))

        assets1=float(input(f"Enter the Total Assets for {year} Q{quarter} " ))
        assets2=float(input(f"Enter the Total Assets for {year-1} Q4 " ))
        assets3=float(input(f"Enter the Total Assets for {year-1} Q3 " ))

        long_term_debt1=float(input(f"Enter Long Term Debts for {year} Q{quarter} " ))
        long_term_debt2=float(input(f"Enter Long Term Debts for {year-1} Q4 " ))

        current_assets1=float(input(f"Enter Total Current Assets for {year} Q{quarter} " ))
        current_assets2=float(input(f"Enter Total Current Assets for {year-1} Q4 " ))
        current_assets3=float(input(f"Enter Total Current Assets for {year-1} Q3 " ))

        current_liabilities1=float(input(f"Enter Total Liabilities for {year} Q{quarter} " ))
        current_liabilities2=float(input(f"Enter Total Liabilities for {year-1} Q4 " ))

        gross_profit1=float(input(f"Enter Gross Profit for {year} Q{quarter} " ))
        gross_profit2=float(input(f"Enter Gross Profit for {year-1} Q4 " ))

        revenue1=float(input(f"Enter revenue for {year} Q{quarter} " ))
        revenue2=float(input(f"Enter revenue for {year-1} Q4 " ))

        #Start of Calculation

        avg_current_assets1=(current_assets1+current_assets2)/2
        avg_current_assets2=(current_assets3+current_assets2)/2

        avg_assets1=(assets1+assets2)/2
        avg_assets2=(assets2+assets3)/2

        cash_flow_op=cfo/avg_assets1

        roa1=net_income1/avg_assets1
        roa2=net_income2/avg_assets2
        delta_roa=roa1-abs(roa2)

        accruals=roa1-abs(cash_flow_op)

        leverage1=long_term_debt1/avg_assets1
        leverage2=long_term_debt2/avg_assets2
        delta_leverage=leverage1-abs(leverage2)

        current_ratio1=((current_assets1+current_assets2)/2)/current_liabilities1
        current_ratio2=((current_assets3+current_assets2)/2)/current_liabilities2
        delta_liquidity=current_ratio1-abs(current_ratio2)

        gmo1=gross_profit1/revenue1
        gmo2=gross_profit2/revenue2
        delta_gmo=gmo1-abs(gmo2)

        atr1=revenue1/avg_assets1
        atr2=revenue2/avg_assets2
        atr=atr1-abs(atr2)

        op=input("Did the company have an equity carve-out in last two years?(Y/N) ")


        print("\n*************************************************Piotroski F-Score*************************************************\n")
        print(f"The ROA of the company for {year} Q{quarter} is {round(roa1,3)}")
        print(f"The CFO of the company for {year} Q{quarter} is {round(cash_flow_op,3)}" )
        print(f"The Delta ROA of the company for {year} Q{quarter} is {delta_roa}" )
        print(f"The Accruals of the company for {year} Q{quarter} is {accruals}" )
        print(f"The Delta Liquidity of the company for {year} Q{quarter} is {delta_liquidity}" )
        print(f"The Delta Leverage of the company for {year} Q{quarter} is {delta_leverage}" )
        print(f"The Delta Gross Margin of the company for {year} Q{quarter} is {delta_gmo}" )
        print(f"The Delta Asset Turnover Ratio of the company for {year} Q{quarter} is {atr}\n" )

        print(f"\nThe Current Ratio of the company for {year} Q{quarter} is {current_ratio1}" )
        print(f"The Leverage of the company for {year} Q{quarter} is {leverage1}" )
        print(f"The Gross Margin of the company for {year} Q{quarter} is {gmo1}" )
        print(f"The Asset Turnover Ratio of the company for {year} Q{quarter} is {atr1}" )

        if(round(roa1,2)>0):
            score=score+1
        if(round(cash_flow_op,2)>0):
            score=score+1
        if(delta_roa>0):
            score=score+1
        if(accruals<0):
            score=score+1
        if(delta_leverage<0):
            score=score+1
        if(delta_liquidity>0):
            score=score+1
        if(delta_gmo>0):
            score=score+1
        if(atr>0):
            score=score+1
        if(op=="N"):
            score=score+1


        print("The Piotroski F-Score is ", score)
        if(score>=8):
            print("It is expected of you to long this stock ")
        if(score<=2):
            print("It is expected of you to short this stock ")
    elif(quarter-2==0):
        #Obtaining Figures
        net_income1=float(input(f"Enter the Net Income for {year} Q{quarter} " ))
        net_income2=float(input(f"Enter the Net Income for {year} Q{quarter-1} " ))

        cfo=float(input(f"Enter Cash Flow from Operations for {year} Q{quarter} " ))

        assets1=float(input(f"Enter the Total Assets for {year} Q{quarter} " ))
        assets2=float(input(f"Enter the Total Assets for {year} Q{quarter-1} " ))
        assets3=float(input(f"Enter the Total Assets for {year-1} Q4 " ))

        long_term_debt1=float(input(f"Enter Long Term Debts for {year} Q{quarter} " ))
        long_term_debt2=float(input(f"Enter Long Term Debts for {year} Q{quarter-1} " ))

        current_assets1=float(input(f"Enter Total Current Assets for {year} Q{quarter} " ))
        current_assets2=float(input(f"Enter Total Current Assets for {year} Q{quarter-1} " ))
        current_assets3=float(input(f"Enter Total Current Assets for {year-1} Q4 " ))

        current_liabilities1=float(input(f"Enter Total Liabilities for {year} Q{quarter} " ))
        current_liabilities2=float(input(f"Enter Total Liabilities for {year} Q{quarter-1} " ))

        gross_profit1=float(input(f"Enter Gross Profit for {year} Q{quarter} " ))
        gross_profit2=float(input(f"Enter Gross Profit for {year} Q{quarter-1} " ))

        revenue1=float(input(f"Enter revenue for {year} Q{quarter} " ))
        revenue2=float(input(f"Enter revenue for {year} Q{quarter-1} " ))

        #Start of Calculation

        avg_current_assets1=(current_assets1+current_assets2)/2
        avg_current_assets2=(current_assets3+current_assets2)/2

        avg_assets1=(assets1+assets2)/2
        avg_assets2=(assets2+assets3)/2

        cash_flow_op=cfo/avg_assets1

        roa1=net_income1/avg_assets1
        roa2=net_income2/avg_assets2
        delta_roa=roa1-abs(roa2)

        accruals=roa1-abs(cash_flow_op)

        leverage1=long_term_debt1/avg_assets1
        leverage2=long_term_debt2/avg_assets2
        delta_leverage=leverage1-abs(leverage2)

        current_ratio1=((current_assets1+current_assets2)/2)/current_liabilities1
        current_ratio2=((current_assets3+current_assets2)/2)/current_liabilities2
        delta_liquidity=current_ratio1-abs(current_ratio2)

        gmo1=gross_profit1/revenue1
        gmo2=gross_profit2/revenue2
        delta_gmo=gmo1-abs(gmo2)

        atr1=revenue1/avg_assets1
        atr2=revenue2/avg_assets2
        atr=atr1-abs(atr2)

        op=input("Did the company have an equity carve-out in last two years?(Y/N) ")


        print("\n*************************************************Piotroski F-Score*************************************************\n")
        print(f"The ROA of the company for {year} Q{quarter} is {round(roa1,3)}")
        print(f"The CFO of the company for {year} Q{quarter} is {round(cash_flow_op,3)}" )
        print(f"The Delta ROA of the company for {year} Q{quarter} is {delta_roa}" )
        print(f"The Accruals of the company for {year} Q{quarter} is {accruals}" )
        print(f"The Delta Liquidity of the company for {year} Q{quarter} is {delta_liquidity}" )
        print(f"The Delta Leverage of the company for {year} Q{quarter} is {delta_leverage}" )
        print(f"The Delta Gross Margin of the company for {year} Q{quarter} is {delta_gmo}" )
        print(f"The Delta Asset Turnover Ratio of the company for {year} Q{quarter} is {atr}\n" )

        print(f"\nThe Current Ratio of the company for {year} Q{quarter} is {current_ratio1}" )
        print(f"The Leverage of the company for {year} Q{quarter} is {leverage1}" )
        print(f"The Gross Margin of the company for {year} Q{quarter} is {gmo1}" )
        print(f"The Asset Turnover Ratio of the company for {year} Q{quarter} is {atr1}" )

        if(round(roa1,2)>0):
            score=score+1
        if(round(cash_flow_op,2)>0):
            score=score+1
        if(delta_roa>0):
            score=score+1
        if(accruals<0):
            score=score+1
        if(delta_leverage<0):
            score=score+1
        if(delta_liquidity>0):
            score=score+1
        if(delta_gmo>0):
            score=score+1
        if(atr>0):
            score=score+1
        if(op=="N"):
            score=score+1


        print("The Piotroski F-Score is ", score)
        if(score>=8):
            print("It is expected of you to long this stock ")
        if(score<=2):
            print("It is expected of you to short this stock ")
    else:
        print('Enter a valid Quarter Number')

else:
    print("\nProgram Successfully Exited\n")
# Out:
# **************************************************PIOTROSKI TRADING ALGORITHM**************************************************
#
#
# 1. Piotroski F-Score on Year End Report
# 2. Piotroski F-Score on Quareterly Generated Report
# 3. Exit
# 2
#
# ***************************************Piotroski F-Score on Quareterly Generated Report****************************************
#
# Enter the year of Financial Report 2018
# Enter the Quarter of Financial Report 1
# Enter the Net Income for 2018 Q1 5
# Enter the Net Income for 2017 Q4 5
# Enter Cash Flow from Operations for 2018 Q1 5
# Enter the Total Assets for 2018 Q1 5
# Enter the Total Assets for 2017 Q4 5
# Enter the Total Assets for 2017 Q3 5
# Enter Long Term Debts for 2018 Q1 5
# Enter Long Term Debts for 2017 Q4 5
# Enter Total Current Assets for 2018 Q1 5
# Enter Total Current Assets for 2017 Q4 5
# Enter Total Current Assets for 2017 Q3 5
# Enter Total Liabilities for 2018 Q1 5
# Enter Total Liabilities for 2017 Q4 5
# ...

# %%
year=int(input("Enter the year of Financial Report "))
quarter=int(input("Enter the Quarter of Financial Report "))
score=0
if(quarter-1!=0 and quarter-2!=0 and quarter<=4):
    #Obtaining Figures
    net_income1=float(input(f"Enter the Net Income for {year} Q{quarter} " ))
    net_income2=float(input(f"Enter the Net Income for {year} Q{quarter-1} " ))

    cfo=float(input(f"Enter Cash Flow from Operations for {year} Q{quarter} " ))

    assets1=float(input(f"Enter the Total Assets for {year} Q{quarter} " ))
    assets2=float(input(f"Enter the Total Assets for {year} Q{quarter-1} " ))
    assets3=float(input(f"Enter the Total Assets for {year} Q{quarter-2} " ))

    long_term_debt1=float(input(f"Enter Long Term Debts for {year} Q{quarter} " ))
    long_term_debt2=float(input(f"Enter Long Term Debts for {year} Q{quarter-1} " ))

    current_assets1=float(input(f"Enter Total Current Assets for {year} Q{quarter} " ))
    current_assets2=float(input(f"Enter Total Current Assets for {year} Q{quarter-1} " ))
    current_assets3=float(input(f"Enter Total Current Assets for {year} Q{quarter-2} " ))

    current_liabilities1=float(input(f"Enter Total Liabilities for {year} Q{quarter} " ))
    current_liabilities2=float(input(f"Enter Total Liabilities for {year} Q{quarter-1} " ))

    gross_profit1=float(input(f"Enter Gross Profit for {year} Q{quarter} " ))
    gross_profit2=float(input(f"Enter Gross Profit for {year} Q{quarter-1} " ))

    revenue1=float(input(f"Enter revenue for {year} Q{quarter} " ))
    revenue2=float(input(f"Enter revenue for {year} Q{quarter-1} " ))

    #Start of Calculation

    avg_current_assets1=(current_assets1+current_assets2)/2
    avg_current_assets2=(current_assets3+current_assets2)/2

    avg_assets1=(assets1+assets2)/2
    avg_assets2=(assets2+assets3)/2

    cash_flow_op=cfo/avg_assets1

    roa1=net_income1/avg_assets1
    roa2=net_income2/avg_assets2
    delta_roa=roa1-abs(roa2)

    accruals=roa1-abs(cash_flow_op)

    leverage1=long_term_debt1/avg_assets1
    leverage2=long_term_debt2/avg_assets2
    delta_leverage=leverage1-abs(leverage2)

    current_ratio1=((current_assets1+current_assets2)/2)/current_liabilities1
    current_ratio2=((current_assets3+current_assets2)/2)/current_liabilities2
    delta_liquidity=current_ratio1-abs(current_ratio2)

    gmo1=gross_profit1/revenue1
    gmo2=gross_profit2/revenue2
    delta_gmo=gmo1-abs(gmo2)

    atr1=revenue1/avg_assets1
    atr2=revenue2/avg_assets2
    atr=atr1-abs(atr2)

    op=input("Did the company have an equity carve-out in last two years?(Y/N) ")


    print("\n*************************************************Piotroski F-Score*************************************************\n")
    print(f"The ROA of the company for {year} Q{quarter} is {round(roa1,3)}")
    print(f"The CFO of the company for {year} Q{quarter} is {round(cash_flow_op,3)}" )
    print(f"The Delta ROA of the company for {year} Q{quarter} is {delta_roa}" )
    print(f"The Accruals of the company for {year} Q{quarter} is {accruals}" )
    print(f"The Delta Liquidity of the company for {year} Q{quarter} is {delta_liquidity}" )
    print(f"The Delta Leverage of the company for {year} Q{quarter} is {delta_leverage}" )
    print(f"The Delta Gross Margin of the company for {year} Q{quarter} is {delta_gmo}" )
    print(f"The Delta Asset Turnover Ratio of the company for {year} Q{quarter} is {atr}\n" )

    print(f"\nThe Current Ratio of the company for {year} Q{quarter} is {current_ratio1}" )
    print(f"The Leverage of the company for {year} Q{quarter} is {leverage1}" )
    print(f"The Gross Margin of the company for {year} Q{quarter} is {gmo1}" )
    print(f"The Asset Turnover Ratio of the company for {year} Q{quarter} is {atr1}" )

    if(round(roa1,2)>0):
        score=score+1
    if(round(cash_flow_op,2)>0):
        score=score+1
    if(delta_roa>0):
        score=score+1
    if(accruals<0):
        score=score+1
    if(delta_leverage<0):
        score=score+1
    if(delta_liquidity>0):
        score=score+1
    if(delta_gmo>0):
        score=score+1
    if(atr>0):
        score=score+1
    if(op=="N"):
        score=score+1


    print("The Piotroski F-Score is ", score)
    if(score>=8):
        print("It is expected of you to long this stock ")
    if(score<=2):
        print("It is expected of you to short this stock ")
elif(quarter-1==0):
    
    net_income1=float(input(f"Enter the Net Income for {year} Q{quarter} " ))
    net_income2=float(input(f"Enter the Net Income for {year-1} Q4 " ))

    cfo=float(input(f"Enter Cash Flow from Operations for {year} Q{quarter} " ))

    assets1=float(input(f"Enter the Total Assets for {year} Q{quarter} " ))
    assets2=float(input(f"Enter the Total Assets for {year-1} Q4 " ))
    assets3=float(input(f"Enter the Total Assets for {year-1} Q3 " ))

    long_term_debt1=float(input(f"Enter Long Term Debts for {year} Q{quarter} " ))
    long_term_debt2=float(input(f"Enter Long Term Debts for {year-1} Q4 " ))

    current_assets1=float(input(f"Enter Total Current Assets for {year} Q{quarter} " ))
    current_assets2=float(input(f"Enter Total Current Assets for {year-1} Q4 " ))
    current_assets3=float(input(f"Enter Total Current Assets for {year-1} Q3 " ))

    current_liabilities1=float(input(f"Enter Total Liabilities for {year} Q{quarter} " ))
    current_liabilities2=float(input(f"Enter Total Liabilities for {year-1} Q4 " ))

    gross_profit1=float(input(f"Enter Gross Profit for {year} Q{quarter} " ))
    gross_profit2=float(input(f"Enter Gross Profit for {year-1} Q4 " ))

    revenue1=float(input(f"Enter revenue for {year} Q{quarter} " ))
    revenue2=float(input(f"Enter revenue for {year-1} Q4 " ))

    #Start of Calculation

    avg_current_assets1=(current_assets1+current_assets2)/2
    avg_current_assets2=(current_assets3+current_assets2)/2

    avg_assets1=(assets1+assets2)/2
    avg_assets2=(assets2+assets3)/2

    cash_flow_op=cfo/avg_assets1

    roa1=net_income1/avg_assets1
    roa2=net_income2/avg_assets2
    delta_roa=roa1-abs(roa2)

    accruals=roa1-abs(cash_flow_op)

    leverage1=long_term_debt1/avg_assets1
    leverage2=long_term_debt2/avg_assets2
    delta_leverage=leverage1-abs(leverage2)

    current_ratio1=((current_assets1+current_assets2)/2)/current_liabilities1
    current_ratio2=((current_assets3+current_assets2)/2)/current_liabilities2
    delta_liquidity=current_ratio1-abs(current_ratio2)

    gmo1=gross_profit1/revenue1
    gmo2=gross_profit2/revenue2
    delta_gmo=gmo1-abs(gmo2)

    atr1=revenue1/avg_assets1
    atr2=revenue2/avg_assets2
    atr=atr1-abs(atr2)

    op=input("Did the company have an equity carve-out in last two years?(Y/N) ")


    print("\n*************************************************Piotroski F-Score*************************************************\n")
    print(f"The ROA of the company for {year} Q{quarter} is {round(roa1,3)}")
    print(f"The CFO of the company for {year} Q{quarter} is {round(cash_flow_op,3)}" )
    print(f"The Delta ROA of the company for {year} Q{quarter} is {delta_roa}" )
    print(f"The Accruals of the company for {year} Q{quarter} is {accruals}" )
    print(f"The Delta Liquidity of the company for {year} Q{quarter} is {delta_liquidity}" )
    print(f"The Delta Leverage of the company for {year} Q{quarter} is {delta_leverage}" )
    print(f"The Delta Gross Margin of the company for {year} Q{quarter} is {delta_gmo}" )
    print(f"The Delta Asset Turnover Ratio of the company for {year} Q{quarter} is {atr}\n" )

    print(f"\nThe Current Ratio of the company for {year} Q{quarter} is {current_ratio1}" )
    print(f"The Leverage of the company for {year} Q{quarter} is {leverage1}" )
    print(f"The Gross Margin of the company for {year} Q{quarter} is {gmo1}" )
    print(f"The Asset Turnover Ratio of the company for {year} Q{quarter} is {atr1}" )

    if(round(roa1,2)>0):
        score=score+1
    if(round(cash_flow_op,2)>0):
        score=score+1
    if(delta_roa>0):
        score=score+1
    if(accruals<0):
        score=score+1
    if(delta_leverage<0):
        score=score+1
    if(delta_liquidity>0):
        score=score+1
    if(delta_gmo>0):
        score=score+1
    if(atr>0):
        score=score+1
    if(op=="N"):
        score=score+1


    print("The Piotroski F-Score is ", score)
    if(score>=8):
        print("It is expected of you to long this stock ")
    if(score<=2):
        print("It is expected of you to short this stock ")
elif(quarter-2==0):
    #Obtaining Figures
    net_income1=float(input(f"Enter the Net Income for {year} Q{quarter} " ))
    net_income2=float(input(f"Enter the Net Income for {year} Q{quarter-1} " ))

    cfo=float(input(f"Enter Cash Flow from Operations for {year} Q{quarter} " ))

    assets1=float(input(f"Enter the Total Assets for {year} Q{quarter} " ))
    assets2=float(input(f"Enter the Total Assets for {year} Q{quarter-1} " ))
    assets3=float(input(f"Enter the Total Assets for {year-1} Q4 " ))

    long_term_debt1=float(input(f"Enter Long Term Debts for {year} Q{quarter} " ))
    long_term_debt2=float(input(f"Enter Long Term Debts for {year} Q{quarter-1} " ))

    current_assets1=float(input(f"Enter Total Current Assets for {year} Q{quarter} " ))
    current_assets2=float(input(f"Enter Total Current Assets for {year} Q{quarter-1} " ))
    current_assets3=float(input(f"Enter Total Current Assets for {year-1} Q4 " ))

    current_liabilities1=float(input(f"Enter Total Liabilities for {year} Q{quarter} " ))
    current_liabilities2=float(input(f"Enter Total Liabilities for {year} Q{quarter-1} " ))

    gross_profit1=float(input(f"Enter Gross Profit for {year} Q{quarter} " ))
    gross_profit2=float(input(f"Enter Gross Profit for {year} Q{quarter-1} " ))

    revenue1=float(input(f"Enter revenue for {year} Q{quarter} " ))
    revenue2=float(input(f"Enter revenue for {year} Q{quarter-1} " ))

    #Start of Calculation

    avg_current_assets1=(current_assets1+current_assets2)/2
    avg_current_assets2=(current_assets3+current_assets2)/2

    avg_assets1=(assets1+assets2)/2
    avg_assets2=(assets2+assets3)/2

    cash_flow_op=cfo/avg_assets1

    roa1=net_income1/avg_assets1
    roa2=net_income2/avg_assets2
    delta_roa=roa1-abs(roa2)

    accruals=roa1-abs(cash_flow_op)

    leverage1=long_term_debt1/avg_assets1
    leverage2=long_term_debt2/avg_assets2
    delta_leverage=leverage1-abs(leverage2)

    current_ratio1=((current_assets1+current_assets2)/2)/current_liabilities1
    current_ratio2=((current_assets3+current_assets2)/2)/current_liabilities2
    delta_liquidity=current_ratio1-abs(current_ratio2)

    gmo1=gross_profit1/revenue1
    gmo2=gross_profit2/revenue2
    delta_gmo=gmo1-abs(gmo2)

    atr1=revenue1/avg_assets1
    atr2=revenue2/avg_assets2
    atr=atr1-abs(atr2)

    op=input("Did the company have an equity carve-out in last two years?(Y/N) ")


    print("\n*************************************************Piotroski F-Score*************************************************\n")
    print(f"The ROA of the company for {year} Q{quarter} is {round(roa1,3)}")
    print(f"The CFO of the company for {year} Q{quarter} is {round(cash_flow_op,3)}" )
    print(f"The Delta ROA of the company for {year} Q{quarter} is {delta_roa}" )
    print(f"The Accruals of the company for {year} Q{quarter} is {accruals}" )
    print(f"The Delta Liquidity of the company for {year} Q{quarter} is {delta_liquidity}" )
    print(f"The Delta Leverage of the company for {year} Q{quarter} is {delta_leverage}" )
    print(f"The Delta Gross Margin of the company for {year} Q{quarter} is {delta_gmo}" )
    print(f"The Delta Asset Turnover Ratio of the company for {year} Q{quarter} is {atr}\n" )

    print(f"\nThe Current Ratio of the company for {year} Q{quarter} is {current_ratio1}" )
    print(f"The Leverage of the company for {year} Q{quarter} is {leverage1}" )
    print(f"The Gross Margin of the company for {year} Q{quarter} is {gmo1}" )
    print(f"The Asset Turnover Ratio of the company for {year} Q{quarter} is {atr1}" )

    if(round(roa1,2)>0):
        score=score+1
    if(round(cash_flow_op,2)>0):
        score=score+1
    if(delta_roa>0):
        score=score+1
    if(accruals<0):
        score=score+1
    if(delta_leverage<0):
        score=score+1
    if(delta_liquidity>0):
        score=score+1
    if(delta_gmo>0):
        score=score+1
    if(atr>0):
        score=score+1
    if(op=="N"):
        score=score+1


    print("The Piotroski F-Score is ", score)
    if(score>=8):
        print("It is expected of you to long this stock ")
    if(score<=2):
        print("It is expected of you to short this stock ")
else:
    print('Enter a valid Quarter Number')
# Out:
# Enter the year of Financial Report 2018
# Enter the Quarter of Financial Report 2
# Enter the Net Income for 2018 Q2 5
# Enter the Net Income for 2018 Q1 5
# Enter Cash Flow from Operations for 2018 Q2 5
# Enter the Total Assets for 2018 Q2 5
# Enter the Total Assets for 2018 Q1 5
# Enter the Total Assets for 2017 Q4 5
# Enter Long Term Debts for 2018 Q2 5
# Enter Long Term Debts for 2018 Q1 5
# Enter Total Current Assets for 2018 Q2 5
# Enter Total Current Assets for 2018 Q1 5
# Enter Total Current Assets for 2017 Q4 5
# Enter Total Liabilities for 2018 Q2 5
# Enter Total Liabilities for 2018 Q1 5
# Enter Gross Profit for 2018 Q2 5
# Enter Gross Profit for 2018 Q1 5
# Enter revenue for 2018 Q2 5
# Enter revenue for 2018 Q1 5
# Did the company have an equity carve-out in last two years?(Y/N) Y
#
# *************************************************Piotroski F-Score*************************************************
#
# The ROA of the company for 2018 Q2 is 1.0
# ...

# %%
op='y'
op='n'
print(op)
# Out:
# n
